# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("car_data.csv")
df
# Out:
#        Unnamed: 0      car_brand        car_model  car_price   car_city  \
# 0               0           Ford        Focus         550000  Astrakhan
# 1               1  Mercedes-Benz    GLA-Class        1820000  Astrakhan
# 2               2          Haval           F7        2600000  Astrakhan
# 3               3         Toyota        Camry        4200000  Astrakhan
# 4               4          OMODA           C5        2125000  Astrakhan
# ...           ...            ...              ...        ...        ...
# 42084       42084          Isuzu      Bighorn         450000    Yakutsk
# 42085       42085         Toyota  Corolla Axio        650000    Yakutsk
# 42086       42086       Daihatsu        Be-Go        1350000    Yakutsk
# 42087       42087          Mazda      Tribute         550000    Yakutsk
# 42088       42088          Lexus        GX460        4000000    Yakutsk
#
#        car_fuel car_transmission car_drive  car_mileage car_country  \
# 0      gasoline           manual       FWD       300000         USA
# 1      gasoline            robot       FWD        88000          DE
# 2      gasoline            robot       4WD        19000          CN
# 3      gasoline        automatic       FWD        30000          JP
# 4      gasoline              CVT       FWD        18824          CN
# ...         ...              ...       ...          ...         ...
# 42084    diesel        automatic       4WD       183212          JP
# 42085  gasoline              CVT       FWD       110000          JP
# 42086  gasoline        automatic       4WD       153000          JP
# 42087  gasoline        automatic       4WD       190000          JP
# 42088  gasoline        automatic       4WD       217000          JP
#
#        car_engine_capacity  car_engine_hp  car_age
# 0                      1.8            125       14
# 1                      1.6            156       10
# 2                      1.5            150        2
# 3                      3.5            249        2
# 4                      1.5            147        2
# ...                    ...            ...      ...
# 42084                  3.1            125       30
# 42085                  1.5            110       13
# 42086                  1.5            109       13
# 42087                  2.0            129       23
# 42088                  4.6            296       13
#
# [42089 rows x 13 columns]

# %%
df.head()
# Out:
#    Unnamed: 0      car_brand      car_model  car_price   car_city  car_fuel  \
# 0           0           Ford      Focus         550000  Astrakhan  gasoline
# 1           1  Mercedes-Benz  GLA-Class        1820000  Astrakhan  gasoline
# 2           2          Haval         F7        2600000  Astrakhan  gasoline
# 3           3         Toyota      Camry        4200000  Astrakhan  gasoline
# 4           4          OMODA         C5        2125000  Astrakhan  gasoline
#
#   car_transmission car_drive  car_mileage car_country  car_engine_capacity  \
# 0           manual       FWD       300000         USA                  1.8
# 1            robot       FWD        88000          DE                  1.6
# 2            robot       4WD        19000          CN                  1.5
# 3        automatic       FWD        30000          JP                  3.5
# 4              CVT       FWD        18824          CN                  1.5
#
#    car_engine_hp  car_age
# 0            125       14
# 1            156       10
# 2            150        2
# 3            249        2
# 4            147        2

# %%
df.tail()
# Out:
#        Unnamed: 0 car_brand        car_model  car_price car_city  car_fuel  \
# 42084       42084     Isuzu      Bighorn         450000  Yakutsk    diesel
# 42085       42085    Toyota  Corolla Axio        650000  Yakutsk  gasoline
# 42086       42086  Daihatsu        Be-Go        1350000  Yakutsk  gasoline
# 42087       42087     Mazda      Tribute         550000  Yakutsk  gasoline
# 42088       42088     Lexus        GX460        4000000  Yakutsk  gasoline
#
#       car_transmission car_drive  car_mileage car_country  \
# 42084        automatic       4WD       183212          JP
# 42085              CVT       FWD       110000          JP
# 42086        automatic       4WD       153000          JP
# 42087        automatic       4WD       190000          JP
# 42088        automatic       4WD       217000          JP
#
#        car_engine_capacity  car_engine_hp  car_age
# 42084                  3.1            125       30
# 42085                  1.5            110       13
# 42086                  1.5            109       13
# 42087                  2.0            129       23
# 42088                  4.6            296       13

# %%
df.dtypes
# Out:
# Unnamed: 0               int64
# car_brand               object
# car_model               object
# car_price                int64
# car_city                object
# car_fuel                object
# car_transmission        object
# car_drive               object
# car_mileage              int64
# car_country             object
# car_engine_capacity    float64
# car_engine_hp            int64
# car_age                  int64
# dtype: object

# %%
df.columns
df= df.rename(columns={'Unnamed: 0':'Sr_no'})
df.columns
# Out:
# Index(['Sr_no', 'car_brand', 'car_model', 'car_price', 'car_city', 'car_fuel',
#        'car_transmission', 'car_drive', 'car_mileage', 'car_country',
#        'car_engine_capacity', 'car_engine_hp', 'car_age'],
#       dtype='object')

# %%
df
# Out:
#        Sr_no      car_brand        car_model  car_price   car_city  car_fuel  \
# 0          0           Ford        Focus         550000  Astrakhan  gasoline
# 1          1  Mercedes-Benz    GLA-Class        1820000  Astrakhan  gasoline
# 2          2          Haval           F7        2600000  Astrakhan  gasoline
# 3          3         Toyota        Camry        4200000  Astrakhan  gasoline
# 4          4          OMODA           C5        2125000  Astrakhan  gasoline
# ...      ...            ...              ...        ...        ...       ...
# 42084  42084          Isuzu      Bighorn         450000    Yakutsk    diesel
# 42085  42085         Toyota  Corolla Axio        650000    Yakutsk  gasoline
# 42086  42086       Daihatsu        Be-Go        1350000    Yakutsk  gasoline
# 42087  42087          Mazda      Tribute         550000    Yakutsk  gasoline
# 42088  42088          Lexus        GX460        4000000    Yakutsk  gasoline
#
#       car_transmission car_drive  car_mileage car_country  \
# 0               manual       FWD       300000         USA
# 1                robot       FWD        88000          DE
# 2                robot       4WD        19000          CN
# 3            automatic       FWD        30000          JP
# 4                  CVT       FWD        18824          CN
# ...                ...       ...          ...         ...
# 42084        automatic       4WD       183212          JP
# 42085              CVT       FWD       110000          JP
# 42086        automatic       4WD       153000          JP
# 42087        automatic       4WD       190000          JP
# 42088        automatic       4WD       217000          JP
#
#        car_engine_capacity  car_engine_hp  car_age
# 0                      1.8            125       14
# 1                      1.6            156       10
# 2                      1.5            150        2
# 3                      3.5            249        2
# 4                      1.5            147        2
# ...                    ...            ...      ...
# 42084                  3.1            125       30
# 42085                  1.5            110       13
# 42086                  1.5            109       13
# 42087                  2.0            129       23
# 42088                  4.6            296       13
#
# [42089 rows x 13 columns]

# %%
df.shape
# Out:
# (42089, 13)

# %%
df.size
# Out:
# 547157

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42089 entries, 0 to 42088
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Sr_no                42089 non-null  int64
#  1   car_brand            42089 non-null  object
#  2   car_model            42089 non-null  object
#  3   car_price            42089 non-null  int64
#  4   car_city             42089 non-null  object
#  5   car_fuel             42089 non-null  object
#  6   car_transmission     42089 non-null  object
#  7   car_drive            42089 non-null  object
#  8   car_mileage          42089 non-null  int64
#  9   car_country          42089 non-null  object
#  10  car_engine_capacity  42089 non-null  float64
#  11  car_engine_hp        42089 non-null  int64
#  12  car_age              42089 non-null  int64
# dtypes: float64(1), int64(5), object(7)
# memory usage: 4.2+ MB

# %%
df.describe()
# Out:
#               Sr_no     car_price    car_mileage  car_engine_capacity  \
# count  42089.000000  4.208900e+04   42089.000000         42089.000000
# mean   21044.000000  1.712717e+06  144846.070517             1.977084
# std    12150.192077  1.976693e+06   92460.616254             0.782458
# min        0.000000  7.000000e+03       1.000000             0.600000
# 25%    10522.000000  7.300000e+05   76500.000000             1.600000
# 50%    21044.000000  1.250000e+06  134500.000000             1.700000
# 75%    31566.000000  2.024900e+06  200000.000000             2.000000
# max    42088.000000  7.000000e+07  996658.000000             8.000000
#
#        car_engine_hp       car_age
# count   42089.000000  42089.000000
# mean      147.329373     11.697261
# std        69.438003      7.379045
# min        30.000000      0.000000
# 25%       105.000000      6.000000
# 50%       130.000000     11.000000
# 75%       170.000000     16.000000
# max      1197.000000     84.000000

# %%
df.isnull()
# Out:
#        Sr_no  car_brand  car_model  car_price  car_city  car_fuel  \
# 0      False      False      False      False     False     False
# 1      False      False      False      False     False     False
# 2      False      False      False      False     False     False
# 3      False      False      False      False     False     False
# 4      False      False      False      False     False     False
# ...      ...        ...        ...        ...       ...       ...
# 42084  False      False      False      False     False     False
# 42085  False      False      False      False     False     False
# 42086  False      False      False      False     False     False
# 42087  False      False      False      False     False     False
# 42088  False      False      False      False     False     False
#
#        car_transmission  car_drive  car_mileage  car_country  \
# 0                 False      False        False        False
# 1                 False      False        False        False
# 2                 False      False        False        False
# 3                 False      False        False        False
# 4                 False      False        False        False
# ...                 ...        ...          ...          ...
# 42084             False      False        False        False
# 42085             False      False        False        False
# 42086             False      False        False        False
# 42087             False      False        False        False
# 42088             False      False        False        False
#
#        car_engine_capacity  car_engine_hp  car_age
# 0                    False          False    False
# 1                    False          False    False
# 2                    False          False    False
# 3                    False          False    False
# 4                    False          False    False
# ...                    ...            ...      ...
# 42084                False          False    False
# 42085                False          False    False
# 42086                False          False    False
# 42087                False          False    False
# 42088                False          False    False
#
# [42089 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# Sr_no                  0
# car_brand              0
# car_model              0
# car_price              0
# car_city               0
# car_fuel               0
# car_transmission       0
# car_drive              0
# car_mileage            0
# car_country            0
# car_engine_capacity    0
# car_engine_hp          0
# car_age                0
# dtype: int64

# %%
df
# Out:
#        Sr_no      car_brand        car_model  car_price   car_city  car_fuel  \
# 0          0           Ford        Focus         550000  Astrakhan  gasoline
# 1          1  Mercedes-Benz    GLA-Class        1820000  Astrakhan  gasoline
# 2          2          Haval           F7        2600000  Astrakhan  gasoline
# 3          3         Toyota        Camry        4200000  Astrakhan  gasoline
# 4          4          OMODA           C5        2125000  Astrakhan  gasoline
# ...      ...            ...              ...        ...        ...       ...
# 42084  42084          Isuzu      Bighorn         450000    Yakutsk    diesel
# 42085  42085         Toyota  Corolla Axio        650000    Yakutsk  gasoline
# 42086  42086       Daihatsu        Be-Go        1350000    Yakutsk  gasoline
# 42087  42087          Mazda      Tribute         550000    Yakutsk  gasoline
# 42088  42088          Lexus        GX460        4000000    Yakutsk  gasoline
#
#       car_transmission car_drive  car_mileage car_country  \
# 0               manual       FWD       300000         USA
# 1                robot       FWD        88000          DE
# 2                robot       4WD        19000          CN
# 3            automatic       FWD        30000          JP
# 4                  CVT       FWD        18824          CN
# ...                ...       ...          ...         ...
# 42084        automatic       4WD       183212          JP
# 42085              CVT       FWD       110000          JP
# 42086        automatic       4WD       153000          JP
# 42087        automatic       4WD       190000          JP
# 42088        automatic       4WD       217000          JP
#
#        car_engine_capacity  car_engine_hp  car_age
# 0                      1.8            125       14
# 1                      1.6            156       10
# 2                      1.5            150        2
# 3                      3.5            249        2
# 4                      1.5            147        2
# ...                    ...            ...      ...
# 42084                  3.1            125       30
# 42085                  1.5            110       13
# 42086                  1.5            109       13
# 42087                  2.0            129       23
# 42088                  4.6            296       13
#
# [42089 rows x 13 columns]

# %%
df.drop(['Sr_no','car_city', 'car_brand', 'car_model'], axis=1, inplace=True)

# %%
df
# Out:
#        car_price  car_fuel car_transmission car_drive  car_mileage  \
# 0         550000  gasoline           manual       FWD       300000
# 1        1820000  gasoline            robot       FWD        88000
# 2        2600000  gasoline            robot       4WD        19000
# 3        4200000  gasoline        automatic       FWD        30000
# 4        2125000  gasoline              CVT       FWD        18824
# ...          ...       ...              ...       ...          ...
# 42084     450000    diesel        automatic       4WD       183212
# 42085     650000  gasoline              CVT       FWD       110000
# 42086    1350000  gasoline        automatic       4WD       153000
# 42087     550000  gasoline        automatic       4WD       190000
# 42088    4000000  gasoline        automatic       4WD       217000
#
#       car_country  car_engine_capacity  car_engine_hp  car_age
# 0             USA                  1.8            125       14
# 1              DE                  1.6            156       10
# 2              CN                  1.5            150        2
# 3              JP                  3.5            249        2
# 4              CN                  1.5            147        2
# ...           ...                  ...            ...      ...
# 42084          JP                  3.1            125       30
# 42085          JP                  1.5            110       13
# 42086          JP                  1.5            109       13
# 42087          JP                  2.0            129       23
# 42088          JP                  4.6            296       13
#
# [42089 rows x 9 columns]

# %%
df.dtypes
# Out:
# car_price                int64
# car_fuel                object
# car_transmission        object
# car_drive               object
# car_mileage              int64
# car_country             object
# car_engine_capacity    float64
# car_engine_hp            int64
# car_age                  int64
# dtype: object

# %%
from sklearn.preprocessing import OrdinalEncoder, StandardScaler
def code_func(data, code, columns = ['car_fuel', 'car_transmission', 'car_drive', 'car_country']):
    df[columns]= code.fit_transform(df[columns])
    return df

# %%
code = OrdinalEncoder()
df = code_func(df, code)

# %%
code.categories_
# Out:
# [array(['diesel', 'gasoline', 'hybrid'], dtype=object),
#  array(['CVT', 'automatic', 'manual', 'robot'], dtype=object),
#  array(['4WD', 'FWD', 'RWD'], dtype=object),
#  array(['CN', 'CZ', 'DE', 'ES', 'FR', 'IR', 'IT', 'JP', 'KR', 'KR ', 'RUS',
#         'SE', 'UK', 'UKR', 'USA', 'UZ'], dtype=object)]

# %%
density = pd.DataFrame()
density['car_price_bins'] = df['car_price'].quantile([0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 0.99, 1.0])
density['car_mileage_bins'] = df['car_mileage'].quantile([0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 0.99, 1.0])

density
# Out:
#       car_price_bins  car_mileage_bins
# 0.70       1820000.0          186000.0
# 0.75       2024900.0          200000.0
# 0.80       2310000.0          218000.0
# 0.85       2700000.0          240000.0
# 0.90       3340000.0          266000.0
# 0.95       4539599.4          306022.2
# 0.99       9300000.0          400000.0
# 1.00      69999999.0          996658.0

# %%
#deleting outliers
data = df.loc[df['car_price'] < df['car_price'].quantile(0.90)]
data = df.loc[df['car_mileage'] < df['car_mileage'].quantile(0.95)]

# %%
data.describe().round(2)
# Out:
#          car_price  car_fuel  car_transmission  car_drive  car_mileage  \
# count     39984.00  39984.00          39984.00   39984.00     39984.00
# mean    1761903.95      0.97              1.19       0.74    132934.05
# std     2010684.38      0.36              0.83       0.55     76776.19
# min        7000.00      0.00              0.00       0.00         1.00
# 25%      770000.00      1.00              1.00       0.00     73000.00
# 50%     1289889.50      1.00              1.00       1.00    128116.50
# 75%     2099000.00      1.00              2.00       1.00    190000.00
# max    69999999.00      2.00              3.00       2.00    306000.00
#
#        car_country  car_engine_capacity  car_engine_hp   car_age
# count     39984.00             39984.00       39984.00  39984.00
# mean          6.66                 1.96         147.26     11.18
# std           3.25                 0.77          70.00      7.08
# min           0.00                 0.60          30.00      0.00
# 25%           7.00                 1.60         105.00      6.00
# 50%           7.00                 1.60         129.00     10.00
# 75%           8.00                 2.00         170.00     15.00
# max          15.00                 8.00        1197.00     84.00

# %%
plt.figure(figsize=[9, 7])
plt.suptitle('Distribution')

plt.subplot(2, 1, 1)
sns.kdeplot(df['car_price'])
plt.xlabel("Price")
plt.ylabel('Density')
plt.axvline(df['car_price'].mean(), label='mean', c='orange')
plt.axvline(df['car_price'].quantile(0.95), label='95% quantile', c='red')
plt.axvline(df['car_price'].quantile(0.99), label='99% quantile', c='violet')
plt.legend()

plt.subplot(2, 1, 2)
sns.kdeplot(df['car_mileage'])
plt.xlabel("Mileage")
plt.ylabel('Density')
plt.axvline(df['car_mileage'].mean(), label='mean', c='orange')
plt.axvline(df['car_mileage'].quantile(0.95), label='95% quantile', c='red')
plt.axvline(df['car_mileage'].quantile(0.99), label='99% quantile', c='violet')
plt.legend()

plt.tight_layout()
plt.show()

# %%
data.corr()
# Out:
#                      car_price  car_fuel  car_transmission  car_drive  \
# car_price             1.000000 -0.178631         -0.100799  -0.340400
# car_fuel             -0.178631  1.000000         -0.113754   0.227016
# car_transmission     -0.100799 -0.113754          1.000000   0.082193
# car_drive            -0.340400  0.227016          0.082193   1.000000
# car_mileage          -0.357850 -0.041958          0.025828   0.044981
# car_country          -0.191524  0.050186         -0.031282   0.067205
# car_engine_capacity   0.454945 -0.222176         -0.093319  -0.389769
# car_engine_hp         0.636072 -0.180646         -0.088786  -0.392226
# car_age              -0.416408 -0.013616          0.045121   0.165702
#
#                      car_mileage  car_country  car_engine_capacity  \
# car_price              -0.357850    -0.191524             0.454945
# car_fuel               -0.041958     0.050186            -0.222176
# car_transmission        0.025828    -0.031282            -0.093319
# car_drive               0.044981     0.067205            -0.389769
# car_mileage             1.000000     0.108621             0.112936
# car_country             0.108621     1.000000            -0.019847
# car_engine_capacity     0.112936    -0.019847             1.000000
# car_engine_hp          -0.043488    -0.209775             0.821993
# car_age                 0.610324     0.171678             0.066758
#
#                      car_engine_hp   car_age
# car_price                 0.636072 -0.416408
# car_fuel                 -0.180646 -0.013616
# car_transmission         -0.088786  0.045121
# car_drive                -0.392226  0.165702
# car_mileage              -0.043488  0.610324
# car_country              -0.209775  0.171678
# car_engine_capacity       0.821993  0.066758
# car_engine_hp             1.000000 -0.129744
# car_age                  -0.129744  1.000000

# %%
plt.figure(figsize=[10, 8])
sns.heatmap(data.corr(), annot=True , fmt = '.2f', annot_kws={"fontsize": 12},
            linewidths=0.25, center= 0.3, cmap= 'coolwarm', square=True)


plt.tight_layout()
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from math import fsum, sqrt
import sklearn.metrics as sm

# %%
r_comparison = pd.DataFrame(columns=['Train RMSE', 'Test RMSE', 'MAE', 'R2', 'MAPE'])

# %%
data_lr = data.copy()

# %% [markdown]
# # linear Regression

# %%
X = data_lr.drop(['car_price'], axis=1)
y = data_lr['car_price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=123,
                                                   stratify=data_lr['car_drive'])
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((27988, 8), (11996, 8), (27988,), (11996,))

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
y_train_pred = lr.predict(X_train)

lr_train_RMSE = round(sqrt(sm.mean_squared_error(y_train, y_train_pred)), 4)
lr_test_RMSE = round(sqrt(sm.mean_squared_error(y_test, y_pred)), 4)
lr_MAE = round(sm.mean_absolute_error(y_test, y_pred), 4)
lr_R2 = round(sm.r2_score(y_test, y_pred), 4)
lr_MAPE = sm.mean_absolute_percentage_error(y_test, y_pred).round(4)

print(f'Train RMSE = {lr_train_RMSE}')
print(f'Test RMSE = {lr_test_RMSE}')
print(f'MAE = {lr_MAE}')
print(f'R2 = {lr_R2}')
print(f'MAPE = {lr_MAPE}')
# Out:
# Train RMSE = 1391822.9774
# Test RMSE = 1217838.6768
# MAE = 655340.4091
# R2 = 0.5981
# MAPE = 0.6845

# %% [markdown]
# # Decision Tree

# %%
data_dt = data.copy()

# %%
X = data_dt.drop(['car_price'], axis=1)
y = data_dt['car_price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=123,
                                                   stratify=data_dt['car_drive'])
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((27988, 8), (11996, 8), (27988,), (11996,))

# %%
tree = DecisionTreeRegressor(random_state=42)
tree.fit(X_train, y_train)
y_pred = tree.predict(X_test)
y_train_pred = tree.predict(X_train)

dt_train_RMSE = round(sqrt(sm.mean_squared_error(y_train, y_train_pred)), 4)
dt_test_RMSE = round(sqrt(sm.mean_squared_error(y_test, y_pred)), 4)
dt_MAE = round(sm.mean_absolute_error(y_test, y_pred), 4)
dt_R2 = round(sm.r2_score(y_test, y_pred), 4)
dt_MAPE = sm.mean_absolute_percentage_error(y_test, y_pred).round(4)

print(f'Train RMSE = {dt_train_RMSE}')
print(f'Test RMSE = {dt_test_RMSE}')
print(f'MAE = {dt_MAE}')
print(f'R2 = {dt_R2}')
print(f'MAPE = {dt_MAPE}')
# Out:
# Train RMSE = 46553.2839
# Test RMSE = 1136149.2626
# MAE = 346066.4272
# R2 = 0.6502
# MAPE = 0.2548

# %% [markdown]
# # Random Forest

# %%
data_rf = data.copy()

# %%
X = data_rf.drop(['car_price'], axis=1)
y = data_rf['car_price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=123,
                                                   stratify=data_rf['car_drive'])
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((27988, 8), (11996, 8), (27988,), (11996,))

# %%
rf = RandomForestRegressor(random_state=42)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
y_train_pred = rf.predict(X_train)

rf_train_RMSE = round(sqrt(sm.mean_squared_error(y_train, y_train_pred)), 4)
rf_test_RMSE = round(sqrt(sm.mean_squared_error(y_test, y_pred)), 4)
rf_MAE = round(sm.mean_absolute_error(y_test, y_pred), 4)
rf_R2 = round(sm.r2_score(y_test, y_pred), 4)
rf_MAPE = sm.mean_absolute_percentage_error(y_test, y_pred).round(4)

print(f'Train RMSE = {rf_train_RMSE}')
print(f'Test RMSE = {rf_test_RMSE}')
print(f'MAE = {rf_MAE}')
print(f'R2 = {rf_R2}')
print(f'MAPE = {rf_MAPE}')
# Out:
# Train RMSE = 288441.4834
# Test RMSE = 686927.9682
# MAE = 261699.8856
# R2 = 0.8721
# MAPE = 0.2047

# %%
plt.figure(figsize = (10,6))
sns.countplot(data = df,x = 'car_age')
plt.xlabel("car age")
plt.ylabel("Count")
plt.title("Car age Distribution")
plt.plot()
# Out:
# []

# %%
colors = ['#59b38a', '#e8b851', '#8b82ed', '#db6b9c']

plt.figure(figsize=(10, 8))

plt.subplot(1, 3, 1)
plt.pie(df['car_fuel'].value_counts(), autopct='%1.1f%%',
        labels=['diesel', 'gasoline', 'hybrid'], colors=colors)


plt.tight_layout()
plt.show()

# %%
colors = ['#59b38a', '#e8b851', '#8b82ed', '#db6b9c']

plt.figure(figsize=(10, 8))
plt.subplot(1, 3, 2)
plt.pie(df['car_transmission'].value_counts(), autopct='%1.1f%%',
        labels=['CVT', 'automatic', 'manual', 'robot'], colors=colors)
plt.tight_layout()
plt.show()

# %%
colors = ['#59b38a', '#e8b851', '#8b82ed', '#db6b9c']
plt.subplot(1, 3, 3)
plt.pie(df['car_drive'].value_counts(), autopct='%1.1f%%',
        labels=['4WD', 'FWD', 'RWD'], colors=colors)
plt.tight_layout()
plt.show()
